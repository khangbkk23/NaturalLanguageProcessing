# %% [markdown]
# # **Language Model and Application for Spelling Error Correction**

# %% [markdown]
# ## Import libraries

# %%
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from collections import Counter, defaultdict
import math
import string

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download("stopwords")
nltk.download("wordnet")

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/dikhangcshcmut/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/dikhangcshcmut/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/dikhangcshcmut/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/dikhangcshcmut/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Import dataset

# %%
# Import dataset from Google Drive on Colab version
# from google.colab import drive
# drive.mount('/content/drive')
# txt_path = '/content/drive/My Drive/Colab Notebooks/Data files/tedtalk.txt'

# Import text file from local

txt_path = './tedtalk.txt'

with open(txt_path, "r", encoding="utf-8") as f:
    data = f.read()

# Print data for testing
print(data[:100])
# Out:
# Thank you so much, Chris. And it's truly a great honor to have the opportunity to come to this stage

# %% [markdown]
# ## Data preprocessing

# %%
def clean_text(text):
  if text is None:
    return ""
  text = re.sub(r"[^a-zA-Z0-9\s.,!?]", "", text)
  text = text.strip()
  return text

def remove_stopwords(tokens):
  if tokens is None:
    return []
  stop_words = set(stopwords.words("english"))
  return [word for word in tokens if word not in stop_words]

def lemmatize(tokens):
  lemmatizer = WordNetLemmatizer()
  return [lemmatizer.lemmatize(word) for word in tokens]

# %%
def preprocessing(text):
  if text is None:
    return []
  # Clean text
  cleaned_text = clean_text(text)
  # Lower text to lowercase
  cleaned_text = cleaned_text.lower()
  # Remove punctuation
  cleaned_text = cleaned_text.translate(str.maketrans("", "", string.punctuation))
  # Tokenize text
  tokens = nltk.word_tokenize(cleaned_text)
  # Remove stopwords
  tokens = remove_stopwords(tokens)
  # Lemmatize
  tokens = lemmatize(tokens)
  final_tokens = [token for token in tokens if token.strip()]
  return final_tokens

# %% [markdown]
# ### Preprocessing to tokens list (words).

# %%
tokens = preprocessing(data)
print("Number of tokens:", len(tokens))
print(tokens[:100])
# Out:
# Number of tokens: 3527657
# ['thank', 'much', 'chris', 'truly', 'great', 'honor', 'opportunity', 'come', 'stage', 'twice', 'im', 'extremely', 'grateful', 'blown', 'away', 'conference', 'want', 'thank', 'many', 'nice', 'comment', 'say', 'night', 'say', 'sincerely', 'partly', 'mock', 'sob', 'need', 'laughter', 'put', 'position', 'laughter', 'flew', 'air', 'force', 'two', 'eight', 'year', 'laughter', 'take', 'shoe', 'boot', 'get', 'airplane', 'laughter', 'applause', 'ill', 'tell', 'one', 'quick', 'story', 'illustrate', 'thats', 'like', 'laughter', 'true', 'story', 'every', 'bit', 'true', 'soon', 'tipper', 'left', 'mock', 'sob', 'white', 'house', 'laughter', 'driving', 'home', 'nashville', 'little', 'farm', '50', 'mile', 'east', 'nashville', 'driving', 'laughter', 'know', 'sound', 'like', 'little', 'thing', 'laughter', 'looked', 'rearview', 'mirror', 'sudden', 'hit', 'motorcade', 'back', 'laughter', 'youve', 'heard', 'phantom', 'limb', 'pain', 'laughter']

# %% [markdown]
# ### Preprocessing to list of sentences

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(data)
processed_sentences = [preprocessing(s) for s in sentences if s.strip()]

print("Number of sentences:", len(processed_sentences))
print("First processed_sentences:", processed_sentences[0])
# Out:
# Number of sentences: 444404
# First processed_sentences: ['thank', 'much', 'chris']

# %% [markdown]
# ## **Build models**

# %% [markdown]
# ### 1-gram model (Unigram model)

# %%
class UnigramModel:
  def __init__(self, tokens):
    self.unigrams = Counter(tokens)
    self.N = sum(self.unigrams.values())
    self.V = len(self.unigrams)

  def get_unigram_prob(self, wi):
    return (self.unigrams[wi] + 1) / (self.N + self.V)

  def sentence_prob(self, sentence_tokens):
    sent = sentence_tokens + ["</s>"]
    log_prob = 0.0
    for wi in sent:
      log_prob += math.log(self.get_unigram_prob(wi))
    return math.exp(log_prob)

  def perplexity(self, sentence_tokens):
    sent = sentence_tokens + ["</s>"]
    N = len(sent)
    log_prob = 0.0
    for wi in sent:
      log_prob += math.log(self.get_unigram_prob(wi))
    return math.exp(-log_prob / N)

# %% [markdown]
# ### 2-gram model (Bigram model)

# %%
class BigramModel:
    def __init__(self, processed_sentences):
        self.unigrams = Counter()
        self.bigrams = Counter()
        for sent in processed_sentences:
            sent2 = ["<s>"] + sent + ["</s>"]
            self.unigrams.update(sent2)
            self.bigrams.update(zip(sent2[:-1], sent2[1:]))
        self.V = len(self.unigrams)

    def get_bigram_prob(self, wi, wi_1):
        return (self.bigrams[(wi_1, wi)] + 1) / (self.unigrams[wi_1] + self.V)

    def sentence_prob(self, sentence_tokens):
        sent2 = ["<s>"] + sentence_tokens + ["</s>"]
        log_prob = 0.0
        for i in range(1, len(sent2)):
            log_prob += math.log(self.get_bigram_prob(sent2[i], sent2[i-1]))
        return math.exp(log_prob)

    def perplexity(self, sentence_tokens):
      sent2 = ["<s>"] + sentence_tokens + ["</s>"]
      N = len(sent2) - 1
      log_prob = 0.0
      for i in range(1, len(sent2)):
        log_prob += math.log(self.get_bigram_prob(sent2[i], sent2[i-1]))
      return math.exp(-log_prob / N)

# %% [markdown]
# ### 3-gram model (Trigram model)

# %%
class TrigramModel:
    def __init__(self, processed_sentences):
        self.unigrams = Counter()
        self.bigrams = Counter()
        self.trigrams = Counter()
        for sent in processed_sentences:
            sent3 = ["<s>", "<s>"] + sent + ["</s>"]
            self.unigrams.update(sent3)
            self.bigrams.update(zip(sent3[:-1], sent3[1:]))
            self.trigrams.update(zip(sent3[:-2], sent3[1:-1], sent3[2:]))
        self.V = len(self.unigrams)

    def get_trigram_prob(self, wi, wi_1, wi_2):
        return (self.trigrams[(wi_2, wi_1, wi)] + 1) / (self.bigrams[(wi_2, wi_1)] + self.V)

    def sentence_prob(self, sentence_tokens):
        sent3 = ["<s>", "<s>"] + sentence_tokens + ["</s>"]
        log_prob = 0.0
        for i in range(2, len(sent3)):
            log_prob += math.log(self.get_trigram_prob(sent3[i], sent3[i-1], sent3[i-2]))
        return math.exp(log_prob)

    def perplexity(self, sentence_tokens):
        sent3 = ["<s>", "<s>"] + sentence_tokens + ["</s>"]
        N = len(sent3) - 2
        log_prob = 0.0
        for i in range(2, len(sent3)):
            log_prob += math.log(self.get_trigram_prob(sent3[i], sent3[i-1], sent3[i-2]))
        return math.exp(-log_prob / N)

# %% [markdown]
# ## Run the models

# %% [markdown]
# ### **b.** Calculate the probability of a sentence and compute the Perplexity of a sentence based on 1-gram, 2-gram, and 3-gram models.

# %%
uni_model = UnigramModel(tokens)
bi_model = BigramModel(processed_sentences)
tri_model = TrigramModel(processed_sentences)

test1 = preprocessing("I love natural language processing")
test2 = preprocessing("Natural language processing I love")
def print_results(name, prob, ppl):
    print(f"{name:<10} | Prob: {prob:.2e} | Perplexity: {ppl:,.2f}")

print_results("Unigram prob:", uni_model.sentence_prob(test1), uni_model.perplexity(test1))
print_results("Bigram prob:", bi_model.sentence_prob(test1), bi_model.perplexity(test1))
print_results("Trigram prob:", tri_model.sentence_prob(test1), tri_model.perplexity(test1))

print("\n-- Wrong order --")
print_results("Unigram prob:", uni_model.sentence_prob(test2), uni_model.perplexity(test2))
print_results("Bigram prob:", bi_model.sentence_prob(test2), bi_model.perplexity(test2))
print_results("Trigram prob:", tri_model.sentence_prob(test2), tri_model.perplexity(test2))
# Out:
# Unigram prob: | Prob: 4.50e-21 | Perplexity: 11,732.28
# Bigram prob: | Prob: 5.50e-19 | Perplexity: 4,486.04
# Trigram prob: | Prob: 2.17e-22 | Perplexity: 21,513.29
#
# -- Wrong order --
# Unigram prob: | Prob: 4.50e-21 | Perplexity: 11,732.28
# Bigram prob: | Prob: 4.55e-19 | Perplexity: 4,659.73
# Trigram prob: | Prob: 3.67e-23 | Perplexity: 30,692.19

# %% [markdown]
# ### **c.** Analyze the results (Provide your own examples of spelling errors and calculate the probability of two similar sentences, where one has the correct word order and the other has an incorrect word order).

# %%
# Compact automated sentence analysis
def analyze_pair(correct, wrong, desc, models):
    print(f"\nTest {models['counter']}: {desc}")

    test_correct = preprocessing(correct)
    test_wrong = preprocessing(wrong)

    uni_prob_correct = models['unigram'].sentence_prob(test_correct)
    uni_ppl_correct = models['unigram'].perplexity(test_correct)
    bi_prob_correct = models['bigram'].sentence_prob(test_correct)
    bi_ppl_correct = models['bigram'].perplexity(test_correct)
    tri_prob_correct = models['trigram'].sentence_prob(test_correct)
    tri_ppl_correct = models['trigram'].perplexity(test_correct)

    uni_prob_wrong = models['unigram'].sentence_prob(test_wrong)
    uni_ppl_wrong = models['unigram'].perplexity(test_wrong)
    bi_prob_wrong = models['bigram'].sentence_prob(test_wrong)
    bi_ppl_wrong = models['bigram'].perplexity(test_wrong)
    tri_prob_wrong = models['trigram'].sentence_prob(test_wrong)
    tri_ppl_wrong = models['trigram'].perplexity(test_wrong)

    probs = {
        'uni': [uni_prob_correct, uni_prob_wrong],
        'bi': [bi_prob_correct, bi_prob_wrong],
        'tri': [tri_prob_correct, tri_prob_wrong]
    }

    print(f"\nCorrect sentence: '{correct}'")
    print_results("Unigram", uni_prob_correct, uni_ppl_correct)
    print_results("Bigram", bi_prob_correct, bi_ppl_correct)
    print_results("Trigram", tri_prob_correct, tri_ppl_correct)

    print(f"\nWrong sentence: '{wrong}'")
    print_results("Unigram", uni_prob_wrong, uni_ppl_wrong)
    print_results("Bigram", bi_prob_wrong, bi_ppl_wrong)
    print_results("Trigram", tri_prob_wrong, tri_ppl_wrong)

    # Check which models correctly identify the right sentence
    results = []
    for name, prob_pair in probs.items():
        if prob_pair[0] > prob_pair[1]:
            ratio = prob_pair[0] / prob_pair[1] if prob_pair[1] > 0 else float('inf')
            results.append(f"{name.upper()}:Can({ratio:.1f}x)")
        else:
            results.append(f"{name.upper()}:Cannot")
    print(" | ".join(results))

    # Store results
    models['results'].append({
        'desc': desc,
        'uni_ok': probs['uni'][0] > probs['uni'][1],
        'bi_ok': probs['bi'][0] > probs['bi'][1],
        'tri_ok': probs['tri'][0] > probs['tri'][1]
    })
    models['counter'] += 1

# Test cases
tests = [
    ("Machine learning is very useful", "Useful very is learning machine", "Word Order"),
    ("Programming languages are important", "Programing languges are importent", "Spelling"),
    ("I enjoy studying computer science", "I enjoys study computer sciences", "Grammar"),
    ("Deep learning models require large datasets", "Deep learning require large datasets", "Missing Word"),
    ("Neural networks can learn patterns", "Neural networks can can learn learn patterns", "Extra Words"),
    ("Python is a programming language", "Python is a dangerous animal", "Semantic Error"),
    ("Data science involves statistics", "Statistics involves data science", "Subject Swap"),
    ("AI will change the world", "AI will changed the world", "Verb Tense")
]

# Initialize
models_dict = {
    'unigram': uni_model, 'bigram': bi_model, 'trigram': tri_model,
    'counter': 1, 'results': []
}

# Run tests
for correct, wrong, desc in tests:
    analyze_pair(correct, wrong, desc, models_dict)

# Summary
results = models_dict['results']
total = len(results)
uni_score = sum(r['uni_ok'] for r in results)
bi_score = sum(r['bi_ok'] for r in results)
tri_score = sum(r['tri_ok'] for r in results)

print("\n__Summary results:___\n")
print(f"Unigram: {uni_score}/{total} ({uni_score/total*100:.0f}%)")
print(f"Bigram:  {bi_score}/{total} ({bi_score/total*100:.0f}%)")
print(f"Trigram: {tri_score}/{total} ({tri_score/total*100:.0f}%)")

best = max(['Unigram', 'Bigram', 'Trigram'], key=lambda x: [uni_score, bi_score, tri_score][['Unigram', 'Bigram', 'Trigram'].index(x)])
print(f"{best}")
# Out:
# Test 1: Word Order
#
# Correct sentence: 'Machine learning is very useful'
# Unigram    | Prob: 8.82e-18 | Perplexity: 18,352.38
# Bigram     | Prob: 2.75e-14 | Perplexity: 2,454.89
# Trigram    | Prob: 2.61e-17 | Perplexity: 13,993.29
#
# Wrong sentence: 'Useful very is learning machine'
# Unigram    | Prob: 8.82e-18 | Perplexity: 18,352.38
# Bigram     | Prob: 5.88e-16 | Perplexity: 6,421.64
# Trigram    | Prob: 2.47e-19 | Perplexity: 44,868.91
# UNI:Cannot | BI:Can(46.8x) | TRI:Can(105.7x)
#
# Test 2: Spelling
#
# Correct sentence: 'Programming languages are important'
# Unigram    | Prob: 8.63e-18 | Perplexity: 18,450.52
# Bigram     | Prob: 1.91e-15 | Perplexity: 4,783.63
# Trigram    | Prob: 2.96e-19 | Perplexity: 42,869.39
#
# Wrong sentence: 'Programing languges are importent'
# Unigram    | Prob: 2.38e-26 | Perplexity: 2,546,162.83
# Bigram     | Prob: 4.94e-21 | Perplexity: 119,302.48
# Trigram    | Prob: 4.94e-21 | Perplexity: 119,301.25
# UNI:Can(362669120.0x) | BI:Can(386870.8x) | TRI:Can(60.0x)
#
# Test 3: Grammar
#
# Correct sentence: 'I enjoy studying computer science'
# Unigram    | Prob: 2.00e-21 | Perplexity: 13,801.54
# Bigram     | Prob: 2.64e-19 | Perplexity: 5,194.43
# Trigram    | Prob: 8.41e-23 | Perplexity: 26,004.31
#
# Wrong sentence: 'I enjoys study computer sciences'
# Unigram    | Prob: 3.76e-22 | Perplexity: 19,269.77
# Bigram     | Prob: 1.21e-20 | Perplexity: 9,621.04
# Trigram    | Prob: 1.75e-24 | Perplexity: 56,397.10
# UNI:Can(5.3x) | BI:Can(21.8x) | TRI:Can(48.0x)
#
# Test 4: Missing Word
#
# Correct sentence: 'Deep learning models require large datasets'
# Unigram    | Prob: 1.81e-30 | Perplexity: 17,731.41
# Bigram     | Prob: 5.92e-31 | Perplexity: 20,806.74
# Trigram    | Prob: 8.96e-33 | Perplexity: 37,863.49
#
# Wrong sentence: 'Deep learning require large datasets'
# Unigram    | Prob: 3.18e-27 | Perplexity: 26,071.33
# Bigram     | Prob: 4.45e-26 | Perplexity: 16,795.84
# Trigram    | Prob: 6.56e-28 | Perplexity: 33,927.82
# UNI:Cannot | BI:Cannot | TRI:Cannot
#
# Test 5: Extra Words
#
# Correct sentence: 'Neural networks can learn patterns'
# Unigram    | Prob: 1.07e-21 | Perplexity: 15,628.98
# Bigram     | Prob: 4.10e-20 | Perplexity: 7,542.38
# Trigram    | Prob: 5.39e-24 | Perplexity: 45,041.05
#
# Wrong sentence: 'Neural networks can can learn learn patterns'
# Unigram    | Prob: 6.56e-25 | Perplexity: 10,727.70
# Bigram     | Prob: 6.52e-24 | Perplexity: 7,315.46
# Trigram    | Prob: 7.37e-29 | Perplexity: 48,833.67
# UNI:Can(1634.5x) | BI:Can(6279.2x) | TRI:Can(73160.0x)
#
# Test 6: Semantic Error
#
# Correct sentence: 'Python is a programming language'
# Unigram    | Prob: 2.39e-20 | Perplexity: 80,433.22
# Bigram     | Prob: 2.46e-17 | Perplexity: 14,199.72
# Trigram    | Prob: 1.48e-20 | Perplexity: 90,652.45
#
# Wrong sentence: 'Python is a dangerous animal'
# Unigram    | Prob: 1.10e-19 | Perplexity: 54,959.43
# Bigram     | Prob: 1.65e-17 | Perplexity: 15,679.91
# Trigram    | Prob: 1.48e-20 | Perplexity: 90,651.83
# UNI:Cannot | BI:Can(1.5x) | TRI:Cannot
#
# Test 7: Subject Swap
#
# Correct sentence: 'Data science involves statistics'
# Unigram    | Prob: 1.18e-21 | Perplexity: 15,342.77
# Bigram     | Prob: 2.02e-20 | Perplexity: 8,685.43
# Trigram    | Prob: 3.67e-23 | Perplexity: 30,694.25
#
# Wrong sentence: 'Statistics involves data science'
# Unigram    | Prob: 1.18e-21 | Perplexity: 15,342.77
# Bigram     | Prob: 2.23e-20 | Perplexity: 8,519.18
# Trigram    | Prob: 6.07e-24 | Perplexity: 43,990.63
# UNI:Cannot | BI:Cannot | TRI:Can(6.0x)
#
# Test 8: Verb Tense
#
# Correct sentence: 'AI will change the world'
# Unigram    | Prob: 2.65e-16 | Perplexity: 7,836.23
# Bigram     | Prob: 1.60e-13 | Perplexity: 1,580.91
# Trigram    | Prob: 3.34e-17 | Perplexity: 13,158.80
#
# Wrong sentence: 'AI will changed the world'
# Unigram    | Prob: 5.37e-17 | Perplexity: 11,680.36
# Bigram     | Prob: 2.22e-14 | Perplexity: 2,591.33
# Trigram    | Prob: 4.53e-18 | Perplexity: 21,679.69
# UNI:Can(4.9x) | BI:Can(7.2x) | TRI:Can(7.4x)
#
# __Summary results:___
#
# Unigram: 4/8 (50%)
# Bigram:  6/8 (75%)
# Trigram: 6/8 (75%)
# Bigram

# %% [markdown]
# # HEX: Optimizing the model for Spelling Error Correction with different smoothing techniques

# %% [markdown]
# ## Interpolation Smoothing with the "Stupid Backoff" method

# %% [markdown]
# ## Build the Stupid Backoff model

# %%
class StupidBackoffModel:
    def __init__(self, processed_sentences, alpha=0.4):
        self.alpha = alpha
        self.processed_sentences = processed_sentences
        self._build_ngram_counts()

    def _build_ngram_counts(self):
        self.unigrams = Counter()
        self.bigrams = Counter()
        self.trigrams = Counter()

        for sent in self.processed_sentences:
            sent_with_markers = ["<s>", "<s>"] + sent + ["</s>"]

            # Count unigrams
            self.unigrams.update(sent_with_markers)

            # Count bigrams
            for i in range(len(sent_with_markers) - 1):
                bigram = (sent_with_markers[i], sent_with_markers[i + 1])
                self.bigrams[bigram] += 1

            # Count trigrams
            for i in range(len(sent_with_markers) - 2):
                trigram = (sent_with_markers[i], sent_with_markers[i + 1], sent_with_markers[i + 2])
                self.trigrams[trigram] += 1

        self.vocab_size = len(self.unigrams)
        self.total_tokens = sum(self.unigrams.values())

    def get_trigram_prob(self, word, context1, context2):
        trigram = (context2, context1, word)
        bigram = (context1, word)

        # Case 1: trigram found
        if self.trigrams[trigram] > 0:
            return self.trigrams[trigram] / self.bigrams[(context2, context1)]

        # Case 2: backoff to bigram
        if self.bigrams[bigram] > 0:
            return self.alpha * (self.bigrams[bigram] / self.unigrams[context1])

        # Case 3: backoff to unigram
        if self.unigrams[word] > 0:
            return (self.alpha ** 2) * (self.unigrams[word] / self.total_tokens)

        # Case 4: completely unseen word
        return 1e-10

    def sentence_prob(self, sentence_tokens):
        sent_with_markers = ["<s>", "<s>"] + sentence_tokens + ["</s>"]
        log_prob = 0.0

        for i in range(2, len(sent_with_markers)):
            word = sent_with_markers[i]
            context1 = sent_with_markers[i - 1]
            context2 = sent_with_markers[i - 2]

            prob = self.get_trigram_prob(word, context1, context2)
            log_prob += math.log(prob if prob > 0 else 1e-10)

        return math.exp(log_prob)

    def perplexity(self, sentence_tokens):
        sent_with_markers = ["<s>", "<s>"] + sentence_tokens + ["</s>"]
        N = len(sent_with_markers) - 2  # exclude start markers
        log_prob = 0.0

        for i in range(2, len(sent_with_markers)):
            word = sent_with_markers[i]
            context1 = sent_with_markers[i - 1]
            context2 = sent_with_markers[i - 2]

            prob = self.get_trigram_prob(word, context1, context2)
            log_prob += math.log(prob if prob > 0 else 1e-10)

        return math.exp(-log_prob / N)

# %% [markdown]
# ## Comparision with in-class model

# %%
# Compact automated sentence analysis with Stupid Backoff
def analyze_pair(correct, wrong, desc, models):
    print(f"\nTest {models['counter']}: {desc}")
    
    test_correct = preprocessing(correct)
    test_wrong = preprocessing(wrong)
    
    # Calculate probabilities and perplexities for all models
    uni_prob_correct = models['unigram'].sentence_prob(test_correct)
    uni_ppl_correct = models['unigram'].perplexity(test_correct)
    bi_prob_correct = models['bigram'].sentence_prob(test_correct)
    bi_ppl_correct = models['bigram'].perplexity(test_correct)
    tri_prob_correct = models['trigram'].sentence_prob(test_correct)
    tri_ppl_correct = models['trigram'].perplexity(test_correct)
    sb_prob_correct = models['stupid_backoff'].sentence_prob(test_correct)
    sb_ppl_correct = models['stupid_backoff'].perplexity(test_correct)
    
    uni_prob_wrong = models['unigram'].sentence_prob(test_wrong)
    uni_ppl_wrong = models['unigram'].perplexity(test_wrong)
    bi_prob_wrong = models['bigram'].sentence_prob(test_wrong)
    bi_ppl_wrong = models['bigram'].perplexity(test_wrong)
    tri_prob_wrong = models['trigram'].sentence_prob(test_wrong)
    tri_ppl_wrong = models['trigram'].perplexity(test_wrong)
    sb_prob_wrong = models['stupid_backoff'].sentence_prob(test_wrong)
    sb_ppl_wrong = models['stupid_backoff'].perplexity(test_wrong)
    
    probs = {
        'uni': [uni_prob_correct, uni_prob_wrong],
        'bi': [bi_prob_correct, bi_prob_wrong],
        'tri': [tri_prob_correct, tri_prob_wrong],
        'sb': [sb_prob_correct, sb_prob_wrong]
    }
    
    print(f"\nCorrect sentence: '{correct}'")
    print_results("Unigram", uni_prob_correct, uni_ppl_correct)
    print_results("Bigram", bi_prob_correct, bi_ppl_correct)
    print_results("Trigram", tri_prob_correct, tri_ppl_correct)
    print_results("Stupid Backoff", sb_prob_correct, sb_ppl_correct)
    
    print(f"\nWrong sentence: '{wrong}'")
    print_results("Unigram", uni_prob_wrong, uni_ppl_wrong)
    print_results("Bigram", bi_prob_wrong, bi_ppl_wrong)
    print_results("Trigram", tri_prob_wrong, tri_ppl_wrong)
    print_results("Stupid Backoff", sb_prob_wrong, sb_ppl_wrong)
    
    # Check which models correctly identify the right sentence
    results = []
    for name, prob_pair in probs.items():
        if prob_pair[0] > prob_pair[1]:
            ratio = prob_pair[0] / prob_pair[1] if prob_pair[1] > 0 else float('inf')
            results.append(f"{name.upper()}: Can({ratio:.1f}x)")
        else:
            results.append(f"{name.upper()}: Cannot")
    print(" | ".join(results))
    
    # Store results
    models['results'].append({
        'desc': desc,
        'uni_ok': probs['uni'][0] > probs['uni'][1],
        'bi_ok': probs['bi'][0] > probs['bi'][1],
        'tri_ok': probs['tri'][0] > probs['tri'][1],
        'sb_ok': probs['sb'][0] > probs['sb'][1]
    })
    models['counter'] += 1

# %% [markdown]
# ### Run the testcases

# %%
tests = [
    ("Machine learning is very useful", "Useful very is learning machine", "Word Order"),
    ("Programming languages are important", "Programing languges are importent", "Spelling"),
    ("I enjoy studying computer science", "I enjoys study computer sciences", "Grammar"),
    ("Deep learning models require large datasets", "Deep learning require large datasets", "Missing Word"),
    ("Neural networks can learn patterns", "Neural networks can can learn learn patterns", "Extra Words"),
    ("Python is a programming language", "Python is a dangerous animal", "Semantic Error"),
    ("Data science involves statistics", "Statistics involves data science", "Subject Swap"),
    ("AI will change the world", "AI will changed the world", "Verb Tense")
]

uni_model = UnigramModel(tokens)
bi_model = BigramModel(processed_sentences)
tri_model = TrigramModel(processed_sentences)
stupid_backoff = StupidBackoffModel(processed_sentences, alpha = 0.8)

models_dict = {
    'unigram': uni_model, 
    'bigram': bi_model, 
    'trigram': tri_model,
    'stupid_backoff': stupid_backoff,
    'counter': 1, 
    'results': []
}

for correct, wrong, desc in tests:
    analyze_pair(correct, wrong, desc, models_dict)

# Summary
results = models_dict['results']
total = len(results)
uni_score = sum(r['uni_ok'] for r in results)
bi_score = sum(r['bi_ok'] for r in results)
tri_score = sum(r['tri_ok'] for r in results)
sb_score = sum(r['sb_ok'] for r in results)

print("\n__Summary results:___\n")
print(f"Unigram:       {uni_score}/{total} ({uni_score/total*100:.0f}%)")
print(f"Bigram:        {bi_score}/{total} ({bi_score/total*100:.0f}%)")
print(f"Trigram:       {tri_score}/{total} ({tri_score/total*100:.0f}%)")
print(f"Stupid Backoff: {sb_score}/{total} ({sb_score/total*100:.0f}%)")

best = max(['Unigram', 'Bigram', 'Trigram', 'Stupid Backoff'], 
          key=lambda x: [uni_score, bi_score, tri_score, sb_score][['Unigram', 'Bigram', 'Trigram', 'Stupid Backoff'].index(x)])
print(f"The most efficient model is: {best}")
# Out:
# Test 1: Word Order
#
# Correct sentence: 'Machine learning is very useful'
# Unigram              | Prob: 2.26e-08 | Perplexity: 81.56
# Bigram               | Prob: 2.07e-07 | Perplexity: 46.90
# Trigram              | Prob: 1.08e-07 | Perplexity: 55.21
# Stupid Backoff       | Prob: 1.63e-04 | Perplexity: 8.85
#
# Wrong sentence: 'Useful very is learning machine'
# Unigram              | Prob: 2.26e-08 | Perplexity: 81.56
# Bigram               | Prob: 2.58e-08 | Perplexity: 78.88
# Trigram              | Prob: 2.76e-08 | Perplexity: 77.56
# Stupid Backoff       | Prob: 2.21e-08 | Perplexity: 82.03
# UNI: Cannot | BI: Can(8.0x) | TRI: Can(3.9x) | SB: Can(7381.2x)
#
# Test 2: Spelling
#
# Correct sentence: 'Programming languages are important'
# Unigram              | Prob: 8.03e-08 | Perplexity: 59.40
# Bigram               | Prob: 1.43e-07 | Perplexity: 51.39
# Trigram              | Prob: 1.06e-07 | Perplexity: 55.40
# Stupid Backoff       | Prob: 1.66e-05 | Perplexity: 15.66
#
# Wrong sentence: 'Programing languges are importent'
# Unigram              | Prob: 1.26e-09 | Perplexity: 168.00
# Bigram               | Prob: 2.76e-08 | Perplexity: 77.56
# Trigram              | Prob: 2.76e-08 | Perplexity: 77.56
# Stupid Backoff       | Prob: 8.15e-32 | Perplexity: 59,179,653.86
# UNI: Can(64.0x) | BI: Can(5.2x) | TRI: Can(3.8x) | SB: Can(203821656050954089384640512.0x)
#
# Test 3: Grammar
#
# Correct sentence: 'I enjoy studying computer science'
# Unigram              | Prob: 1.79e-10 | Perplexity: 88.97
# Bigram               | Prob: 1.13e-08 | Perplexity: 38.83
# Trigram              | Prob: 1.15e-08 | Perplexity: 38.73
# Stupid Backoff       | Prob: 5.00e-02 | Perplexity: 1.82
#
# Wrong sentence: 'I enjoys study computer sciences'
# Unigram              | Prob: 4.48e-11 | Perplexity: 117.40
# Bigram               | Prob: 1.45e-09 | Perplexity: 58.54
# Trigram              | Prob: 7.47e-10 | Perplexity: 66.89
# Stupid Backoff       | Prob: 3.26e-23 | Perplexity: 31,428.67
# UNI: Can(4.0x) | BI: Can(7.8x) | TRI: Can(15.4x) | SB: Can(1533203125000002076672.0x)
#
# Test 4: Missing Word
#
# Correct sentence: 'Deep learning models require large datasets'
# Unigram              | Prob: 6.35e-14 | Perplexity: 76.79
# Bigram               | Prob: 7.95e-12 | Perplexity: 38.52
# Trigram              | Prob: 8.38e-12 | Perplexity: 38.23
# Stupid Backoff       | Prob: 5.00e-02 | Perplexity: 1.53
#
# Wrong sentence: 'Deep learning require large datasets'
# Unigram              | Prob: 2.13e-12 | Perplexity: 88.13
# Bigram               | Prob: 1.53e-10 | Perplexity: 43.24
# Trigram              | Prob: 7.86e-11 | Perplexity: 48.32
# Stupid Backoff       | Prob: 1.63e-04 | Perplexity: 4.28
# UNI: Cannot | BI: Cannot | TRI: Cannot | SB: Can(306.6x)
#
# Test 5: Extra Words
#
# Correct sentence: 'Neural networks can learn patterns'
# Unigram              | Prob: 1.20e-10 | Perplexity: 96.49
# Bigram               | Prob: 5.74e-09 | Perplexity: 44.49
# Trigram              | Prob: 2.91e-09 | Perplexity: 50.97
# Stupid Backoff       | Prob: 1.63e-04 | Perplexity: 5.72
#
# Wrong sentence: 'Neural networks can can learn learn patterns'
# Unigram              | Prob: 1.42e-12 | Perplexity: 94.29
# Bigram               | Prob: 7.75e-11 | Perplexity: 48.43
# Trigram              | Prob: 3.98e-11 | Perplexity: 54.11
# Stupid Backoff       | Prob: 6.65e-07 | Perplexity: 10.70
# UNI: Can(84.0x) | BI: Can(74.0x) | TRI: Can(73.0x) | SB: Can(245.3x)
#
# Test 6: Semantic Error
#
# Correct sentence: 'Python is a programming language'
# Unigram              | Prob: 8.03e-08 | Perplexity: 59.40
# Bigram               | Prob: 2.87e-07 | Perplexity: 43.21
# Trigram              | Prob: 1.06e-07 | Perplexity: 55.40
# Stupid Backoff       | Prob: 1.63e-04 | Perplexity: 8.85
#
# Wrong sentence: 'Python is a dangerous animal'
# Unigram              | Prob: 2.51e-09 | Perplexity: 141.27
# Bigram               | Prob: 5.45e-08 | Perplexity: 65.44
# Trigram              | Prob: 5.45e-08 | Perplexity: 65.44
# Stupid Backoff       | Prob: 4.08e-23 | Perplexity: 395,758.20
# UNI: Can(32.0x) | BI: Can(5.3x) | TRI: Can(1.9x) | SB: Can(4000000000000009728.0x)
#
# Test 7: Subject Swap
#
# Correct sentence: 'Data science involves statistics'
# Unigram              | Prob: 2.69e-10 | Perplexity: 82.04
# Bigram               | Prob: 5.59e-09 | Perplexity: 44.73
# Trigram              | Prob: 5.74e-09 | Perplexity: 44.49
# Stupid Backoff       | Prob: 4.08e-03 | Perplexity: 3.01
#
# Wrong sentence: 'Statistics involves data science'
# Unigram              | Prob: 2.69e-10 | Perplexity: 82.04
# Bigram               | Prob: 1.40e-09 | Perplexity: 59.02
# Trigram              | Prob: 3.74e-10 | Perplexity: 76.83
# Stupid Backoff       | Prob: 2.17e-08 | Perplexity: 34.10
# UNI: Cannot | BI: Can(4.0x) | TRI: Can(15.4x) | SB: Can(188056.9x)
#
# Test 8: Verb Tense
#
# Correct sentence: 'AI will change the world'
# Unigram              | Prob: 1.26e-09 | Perplexity: 168.00
# Bigram               | Prob: 2.76e-08 | Perplexity: 77.56
# Trigram              | Prob: 2.76e-08 | Perplexity: 77.56
# Stupid Backoff       | Prob: 8.15e-32 | Perplexity: 59,179,653.86
#
# Wrong sentence: 'AI will changed the world'
# Unigram              | Prob: 1.26e-09 | Perplexity: 168.00
# Bigram               | Prob: 2.76e-08 | Perplexity: 77.56
# Trigram              | Prob: 2.76e-08 | Perplexity: 77.56
# Stupid Backoff       | Prob: 8.15e-32 | Perplexity: 59,179,653.86
# UNI: Cannot | BI: Cannot | TRI: Cannot | SB: Cannot
#
# __Summary results:___
#
# Unigram:       4/8 (50%)
# Bigram:        6/8 (75%)
# Trigram:       6/8 (75%)
# Stupid Backoff: 7/8 (88%)
# The most efficient model is: Stupid Backoff

# %% [markdown]
# ## Combine with a function that calculates the distance between words to predict the correct word for a misspelled word position.

# %%
from difflib import get_close_matches

class StupidBackoffAdvancedModel:
    def __init__(self, processed_sentences, alpha=0.4):
        self.alpha = alpha
        self.processed_sentences = processed_sentences
        self._build_ngram_counts()
        self._build_vocabulary()
    
    def _build_ngram_counts(self):
        self.unigrams = Counter()
        self.bigrams = Counter()
        self.trigrams = Counter()
        
        for sent in self.processed_sentences:
            sent_with_markers = ["<s>", "<s>"] + sent + ["</s>"]
            
            # Count unigrams
            self.unigrams.update(sent_with_markers)
            
            # Count bigrams
            for i in range(len(sent_with_markers) - 1):
                bigram = (sent_with_markers[i], sent_with_markers[i + 1])
                self.bigrams[bigram] += 1
            
            # Count trigrams
            for i in range(len(sent_with_markers) - 2):
                trigram = (sent_with_markers[i], sent_with_markers[i + 1], sent_with_markers[i + 2])
                self.trigrams[trigram] += 1
        
        self.vocab_size = len(self.unigrams)
        self.total_tokens = sum(self.unigrams.values())
    
    def _build_vocabulary(self):
        self.vocabulary = set()
        for sent in self.processed_sentences:
            self.vocabulary.update(sent)
        # Remove sentence markers from vocabulary for spell correction
        self.vocabulary.discard('<s>')
        self.vocabulary.discard('</s>')
        self.vocab_list = list(self.vocabulary)
    
    def get_trigram_prob(self, word, context1, context2):
        trigram = (context2, context1, word)
        bigram = (context1, word)
        
        # Case 1: trigram found
        if self.trigrams[trigram] > 0:
            return self.trigrams[trigram] / self.bigrams[(context2, context1)]
        # Case 2: backoff to bigram
        if self.bigrams[bigram] > 0:
            return self.alpha * (self.bigrams[bigram] / self.unigrams[context1])
        # Case 3: backoff to unigram
        if self.unigrams[word] > 0:
            return (self.alpha ** 2) * (self.unigrams[word] / self.total_tokens)
        # Case 4: completely unseen word
        return 1e-10
    
    def find_spelling_candidates(self, misspelled_word, n_candidates=3):
        if misspelled_word in self.vocabulary:
            return [misspelled_word]
        
        # Use difflib to find close matches
        candidates = get_close_matches(
            misspelled_word,
            self.vocab_list,
            n=n_candidates,
            cutoff=0.6
        )
        
        return candidates if candidates else [misspelled_word]
    
    def correct_word_in_context(self, misspelled_word, context1, context2):
        candidates = self.find_spelling_candidates(misspelled_word)
        if len(candidates) == 1 and candidates[0] == misspelled_word:
            prob = self.get_trigram_prob(misspelled_word, context1, context2)
            return {
                'original': misspelled_word,
                'correction': misspelled_word,
                'candidates': [(misspelled_word, prob)],
                'corrected': False
            }
        
        candidate_probs = []
        for candidate in candidates:
            prob = self.get_trigram_prob(candidate, context1, context2)
            candidate_probs.append((candidate, prob))
        
        candidate_probs.sort(key=lambda x: x[1], reverse=True)
        best_candidate = candidate_probs[0][0]
        
        return {
            'original': misspelled_word,
            'correction': best_candidate,
            'candidates': candidate_probs,
            'corrected': best_candidate != misspelled_word
        }
    
    def sentence_prob_with_correction(self, sentence_tokens, apply_correction=True):
        sent_with_markers = ["<s>", "<s>"] + sentence_tokens + ["</s>"]
        original_log_prob = 0.0
        corrected_log_prob = 0.0
        corrections = []
        corrected_tokens = []
        
        for i in range(2, len(sent_with_markers)):
            word = sent_with_markers[i]
            context1 = sent_with_markers[i - 1]
            context2 = sent_with_markers[i - 2]
            
            # Original probability
            original_prob = self.get_trigram_prob(word, context1, context2)
            original_log_prob += math.log(original_prob if original_prob > 0 else 1e-10)
            
            if apply_correction and word not in ['<s>', '</s>']:
                correction_result = self.correct_word_in_context(word, context1, context2)
                corrections.append(correction_result)
                corrected_word = correction_result['correction']
                corrected_tokens.append(corrected_word)
                
                # Update sentence markers for next iteration
                sent_with_markers[i] = corrected_word
                
                # Corrected probability
                corrected_prob = self.get_trigram_prob(corrected_word, context1, context2)
                corrected_log_prob += math.log(corrected_prob if corrected_prob > 0 else 1e-10)
            else:
                corrected_tokens.append(word)
                corrected_log_prob += math.log(original_prob if original_prob > 0 else 1e-10)
        
        return {
            'original_prob': math.exp(original_log_prob),
            'corrected_prob': math.exp(corrected_log_prob),
            'corrections': corrections,
            'corrected_tokens': corrected_tokens
        }
    
    def sentence_prob(self, sentence_tokens):
        sent_with_markers = ["<s>", "<s>"] + sentence_tokens + ["</s>"]
        log_prob = 0.0
        
        for i in range(2, len(sent_with_markers)):
            word = sent_with_markers[i]
            context1 = sent_with_markers[i - 1]
            context2 = sent_with_markers[i - 2]
            
            prob = self.get_trigram_prob(word, context1, context2)
            log_prob += math.log(prob if prob > 0 else 1e-10)
        
        return math.exp(log_prob)
    
    def perplexity(self, sentence_tokens):
        sent_with_markers = ["<s>", "<s>"] + sentence_tokens + ["</s>"]
        N = len(sent_with_markers) - 2  # exclude start markers
        log_prob = 0.0
        
        for i in range(2, len(sent_with_markers)):
            word = sent_with_markers[i]
            context1 = sent_with_markers[i - 1]
            context2 = sent_with_markers[i - 2]
            
            prob = self.get_trigram_prob(word, context1, context2)
            log_prob += math.log(prob if prob > 0 else 1e-10)
        
        return math.exp(-log_prob / N)

# %%
# Compact analysis function with Advanced Stupid Backoff
def analyze_pair_advanced(correct, wrong, desc, models):
    print(f"\nTest {models['counter']}: {desc}")
    
    test_correct = preprocessing(correct)
    test_wrong = preprocessing(wrong)
    
    # Calculate probabilities and perplexities for all models
    uni_prob_correct = models['unigram'].sentence_prob(test_correct)
    uni_ppl_correct = models['unigram'].perplexity(test_correct)
    bi_prob_correct = models['bigram'].sentence_prob(test_correct)
    bi_ppl_correct = models['bigram'].perplexity(test_correct)
    tri_prob_correct = models['trigram'].sentence_prob(test_correct)
    tri_ppl_correct = models['trigram'].perplexity(test_correct)
    sb_prob_correct = models['stupid_backoff'].sentence_prob(test_correct)
    sb_ppl_correct = models['stupid_backoff'].perplexity(test_correct)
    sba_prob_correct = models['stupid_backoff_advanced'].sentence_prob(test_correct)
    sba_ppl_correct = models['stupid_backoff_advanced'].perplexity(test_correct)
    
    uni_prob_wrong = models['unigram'].sentence_prob(test_wrong)
    uni_ppl_wrong = models['unigram'].perplexity(test_wrong)
    bi_prob_wrong = models['bigram'].sentence_prob(test_wrong)
    bi_ppl_wrong = models['bigram'].perplexity(test_wrong)
    tri_prob_wrong = models['trigram'].sentence_prob(test_wrong)
    tri_ppl_wrong = models['trigram'].perplexity(test_wrong)
    sb_prob_wrong = models['stupid_backoff'].sentence_prob(test_wrong)
    sb_ppl_wrong = models['stupid_backoff'].perplexity(test_wrong)
    sba_prob_wrong = models['stupid_backoff_advanced'].sentence_prob(test_wrong)
    sba_ppl_wrong = models['stupid_backoff_advanced'].perplexity(test_wrong)
    
    probs = {
        'uni': [uni_prob_correct, uni_prob_wrong],
        'bi': [bi_prob_correct, bi_prob_wrong],
        'tri': [tri_prob_correct, tri_prob_wrong],
        'sb': [sb_prob_correct, sb_prob_wrong],
        'sba': [sba_prob_correct, sba_prob_wrong]
    }
    
    print(f"\nCorrect sentence: '{correct}'")
    print_results("Unigram", uni_prob_correct, uni_ppl_correct)
    print_results("Bigram", bi_prob_correct, bi_ppl_correct)
    print_results("Trigram", tri_prob_correct, tri_ppl_correct)
    print_results("Stupid Backoff", sb_prob_correct, sb_ppl_correct)
    print_results("SB + Spell Correct", sba_prob_correct, sba_ppl_correct)
    
    print(f"\nWrong sentence: '{wrong}'")
    print_results("Unigram", uni_prob_wrong, uni_ppl_wrong)
    print_results("Bigram", bi_prob_wrong, bi_ppl_wrong)
    print_results("Trigram", tri_prob_wrong, tri_ppl_wrong)
    print_results("Stupid Backoff", sb_prob_wrong, sb_ppl_wrong)
    print_results("SB + Spell Correct", sba_prob_wrong, sba_ppl_wrong)
    

    results = []
    model_names = ['UNI', 'BI', 'TRI', 'SB', 'SBA']
    for i, (name, prob_pair) in enumerate(zip(model_names, probs.values())):
        if prob_pair[0] > prob_pair[1]:
            ratio = prob_pair[0] / prob_pair[1] if prob_pair[1] > 0 else float('inf')
            results.append(f"{name}:Can({ratio:.1f}x)")
        else:
            results.append(f"{name}:Cannot")
    print(" | ".join(results))
    
    if any(char.isalpha() and char not in correct.lower() for char in wrong.lower()):
        correction_result = models['stupid_backoff_advanced'].sentence_prob_with_correction(test_wrong)
        corrections_made = [c for c in correction_result['corrections'] if c['corrected']]
        if corrections_made:
            print(f"Original: {' '.join(test_wrong)}")
            print(f"Corrected: {' '.join(correction_result['corrected_tokens'])}")
            print(f"Improvement: {correction_result['corrected_prob']/correction_result['original_prob']:.1f}x")
            for correction in corrections_made:
                print(f"  {correction['original']} → {correction['correction']}")

    models['results'].append({
        'desc': desc,
        'uni_ok': probs['uni'][0] > probs['uni'][1],
        'bi_ok': probs['bi'][0] > probs['bi'][1],
        'tri_ok': probs['tri'][0] > probs['tri'][1],
        'sb_ok': probs['sb'][0] > probs['sb'][1],
        'sba_ok': probs['sba'][0] > probs['sba'][1]
    })
    models['counter'] += 1

# %%
tests_advanced = [
    ("Machine learning is very useful", "Useful very is learning machine", "Word Order"),
    ("Programming languages are important", "Programing languges are importent", "Spelling Errors"),
    ("I enjoy studying computer science", "I enjoys study computer sciences", "Grammar Errors"),
    ("Deep learning models require large datasets", "Deep learning require large datasets", "Missing Word"),
    ("Neural networks can learn patterns", "Neural networks can can learn learn patterns", "Extra Words"),
    ("Python is a programming language", "Python is a dangerous animal", "Semantic Error"),
    ("Data science involves statistics", "Statistics involves data science", "Subject Swap"),
    ("Natural language processing is fascinating", "Naturel languag procesing is fascinatng", "Multiple Spelling"),
    ("Artificial intelligence will change the world", "Artifical inteligence wil chang the worlld", "Heavy Spelling"),
    ("Statistical methods are important in NLP", "Statisticl methds ar importnt in NLP", "Mixed Errors")
]
models_dict_advanced = {
    'unigram': uni_model,
    'bigram': bi_model, 
    'trigram': tri_model,
    'stupid_backoff': stupid_backoff,
    'stupid_backoff_advanced': StupidBackoffAdvancedModel(processed_sentences, alpha=0.7),  # Advanced with spell correction
    'counter': 1, 
    'results': []
}
for correct, wrong, desc in tests_advanced:
    analyze_pair_advanced(correct, wrong, desc, models_dict_advanced)

# Summary
results = models_dict_advanced['results']
total = len(results)
uni_score = sum(r['uni_ok'] for r in results)
bi_score = sum(r['bi_ok'] for r in results)
tri_score = sum(r['tri_ok'] for r in results)
sb_score = sum(r['sb_ok'] for r in results)
sba_score = sum(r['sba_ok'] for r in results)

print("\n__Summary results:___\n")
print(f"Total tests: {total}")
print(f"Unigram:              {uni_score}/{total} ({uni_score/total*100:.0f}%)")
print(f"Bigram:               {bi_score}/{total} ({bi_score/total*100:.0f}%)")
print(f"Trigram:              {tri_score}/{total} ({tri_score/total*100:.0f}%)")
print(f"Stupid Backoff:       {sb_score}/{total} ({sb_score/total*100:.0f}%)")
print(f"SB + Spell Correct:   {sba_score}/{total} ({sba_score/total*100:.0f}%)")

best = max(['Unigram', 'Bigram', 'Trigram', 'Stupid Backoff', 'SB + Spell Correct'], 
          key=lambda x: [uni_score, bi_score, tri_score, sb_score, sba_score][['Unigram', 'Bigram', 'Trigram', 'Stupid Backoff', 'SB + Spell Correct'].index(x)])

print(f"\n The most effective model is: {best}")
# Out:
# Test 1: Word Order
#
# Correct sentence: 'Machine learning is very useful'
# Unigram              | Prob: 2.26e-08 | Perplexity: 81.56
# Bigram               | Prob: 2.07e-07 | Perplexity: 46.90
# Trigram              | Prob: 1.08e-07 | Perplexity: 55.21
# Stupid Backoff       | Prob: 1.63e-04 | Perplexity: 8.85
# SB + Spell Correct   | Prob: 1.09e-04 | Perplexity: 9.78
#
# Wrong sentence: 'Useful very is learning machine'
# Unigram              | Prob: 2.26e-08 | Perplexity: 81.56
# Bigram               | Prob: 2.58e-08 | Perplexity: 78.88
# Trigram              | Prob: 2.76e-08 | Perplexity: 77.56
# Stupid Backoff       | Prob: 2.21e-08 | Perplexity: 82.03
# SB + Spell Correct   | Prob: 7.59e-09 | Perplexity: 107.13
# UNI:Cannot | BI:Can(8.0x) | TRI:Can(3.9x) | SB:Can(7381.2x) | SBA:Can(14390.9x)
#
# Test 2: Spelling Errors
#
# Correct sentence: 'Programming languages are important'
# Unigram              | Prob: 8.03e-08 | Perplexity: 59.40
# Bigram               | Prob: 1.43e-07 | Perplexity: 51.39
# Trigram              | Prob: 1.06e-07 | Perplexity: 55.40
# Stupid Backoff       | Prob: 1.66e-05 | Perplexity: 15.66
# SB + Spell Correct   | Prob: 9.74e-06 | Perplexity: 17.90
#
# Wrong sentence: 'Programing languges are importent'
# Unigram              | Prob: 1.26e-09 | Perplexity: 168.00
# Bigram               | Prob: 2.76e-08 | Perplexity: 77.56
# Trigram              | Prob: 2.76e-08 | Perplexity: 77.56
# Stupid Backoff       | Prob: 8.15e-32 | Perplexity: 59,179,653.86
# SB + Spell Correct   | Prob: 6.24e-32 | Perplexity: 63,265,711.15
# UNI:Can(64.0x) | BI:Can(5.2x) | TRI:Can(3.8x) | SB:Can(203821656050954089384640512.0x) | SBA:Can(156050955414012766751555584.0x)
#
# Test 3: Grammar Errors
#
# Correct sentence: 'I enjoy studying computer science'
# Unigram              | Prob: 1.79e-10 | Perplexity: 88.97
# Bigram               | Prob: 1.13e-08 | Perplexity: 38.83
# Trigram              | Prob: 1.15e-08 | Perplexity: 38.73
# Stupid Backoff       | Prob: 5.00e-02 | Perplexity: 1.82
# SB + Spell Correct   | Prob: 5.00e-02 | Perplexity: 1.82
#
# Wrong sentence: 'I enjoys study computer sciences'
# Unigram              | Prob: 4.48e-11 | Perplexity: 117.40
# Bigram               | Prob: 1.45e-09 | Perplexity: 58.54
# Trigram              | Prob: 7.47e-10 | Perplexity: 66.89
# Stupid Backoff       | Prob: 3.26e-23 | Perplexity: 31,428.67
# SB + Spell Correct   | Prob: 2.18e-23 | Perplexity: 34,050.31
# UNI:Can(4.0x) | BI:Can(7.8x) | TRI:Can(15.4x) | SB:Can(1533203125000002076672.0x) | SBA:Can(2288629737609341435904.0x)
#
# Test 4: Missing Word
#
# Correct sentence: 'Deep learning models require large datasets'
# Unigram              | Prob: 6.35e-14 | Perplexity: 76.79
# Bigram               | Prob: 7.95e-12 | Perplexity: 38.52
# Trigram              | Prob: 8.38e-12 | Perplexity: 38.23
# Stupid Backoff       | Prob: 5.00e-02 | Perplexity: 1.53
# SB + Spell Correct   | Prob: 5.00e-02 | Perplexity: 1.53
#
# Wrong sentence: 'Deep learning require large datasets'
# Unigram              | Prob: 2.13e-12 | Perplexity: 88.13
# Bigram               | Prob: 1.53e-10 | Perplexity: 43.24
# Trigram              | Prob: 7.86e-11 | Perplexity: 48.32
# Stupid Backoff       | Prob: 1.63e-04 | Perplexity: 4.28
# SB + Spell Correct   | Prob: 1.09e-04 | Perplexity: 4.57
# UNI:Cannot | BI:Cannot | TRI:Cannot | SB:Can(306.6x) | SBA:Can(457.7x)
#
# Test 5: Extra Words
#
# Correct sentence: 'Neural networks can learn patterns'
# Unigram              | Prob: 1.20e-10 | Perplexity: 96.49
# Bigram               | Prob: 5.74e-09 | Perplexity: 44.49
# Trigram              | Prob: 2.91e-09 | Perplexity: 50.97
# Stupid Backoff       | Prob: 1.63e-04 | Perplexity: 5.72
# SB + Spell Correct   | Prob: 1.09e-04 | Perplexity: 6.20
#
# Wrong sentence: 'Neural networks can can learn learn patterns'
# Unigram              | Prob: 1.42e-12 | Perplexity: 94.29
# Bigram               | Prob: 7.75e-11 | Perplexity: 48.43
# Trigram              | Prob: 3.98e-11 | Perplexity: 54.11
# Stupid Backoff       | Prob: 6.65e-07 | Perplexity: 10.70
# SB + Spell Correct   | Prob: 3.41e-07 | Perplexity: 11.96
# UNI:Can(84.0x) | BI:Can(74.0x) | TRI:Can(73.0x) | SB:Can(245.3x) | SBA:Can(320.4x)
#
# Test 6: Semantic Error
#
# Correct sentence: 'Python is a programming language'
# Unigram              | Prob: 8.03e-08 | Perplexity: 59.40
# Bigram               | Prob: 2.87e-07 | Perplexity: 43.21
# Trigram              | Prob: 1.06e-07 | Perplexity: 55.40
# Stupid Backoff       | Prob: 1.63e-04 | Perplexity: 8.85
# SB + Spell Correct   | Prob: 1.09e-04 | Perplexity: 9.78
#
# Wrong sentence: 'Python is a dangerous animal'
# Unigram              | Prob: 2.51e-09 | Perplexity: 141.27
# Bigram               | Prob: 5.45e-08 | Perplexity: 65.44
# Trigram              | Prob: 5.45e-08 | Perplexity: 65.44
# Stupid Backoff       | Prob: 4.08e-23 | Perplexity: 395,758.20
# SB + Spell Correct   | Prob: 3.12e-23 | Perplexity: 423,083.31
# UNI:Can(32.0x) | BI:Can(5.3x) | TRI:Can(1.9x) | SB:Can(4000000000000009728.0x) | SBA:Can(3500000000000007680.0x)
#
# Test 7: Subject Swap
#
# Correct sentence: 'Data science involves statistics'
# Unigram              | Prob: 2.69e-10 | Perplexity: 82.04
# Bigram               | Prob: 5.59e-09 | Perplexity: 44.73
# Trigram              | Prob: 5.74e-09 | Perplexity: 44.49
# Stupid Backoff       | Prob: 4.08e-03 | Perplexity: 3.01
# SB + Spell Correct   | Prob: 3.12e-03 | Perplexity: 3.17
#
# Wrong sentence: 'Statistics involves data science'
# Unigram              | Prob: 2.69e-10 | Perplexity: 82.04
# Bigram               | Prob: 1.40e-09 | Perplexity: 59.02
# Trigram              | Prob: 3.74e-10 | Perplexity: 76.83
# Stupid Backoff       | Prob: 2.17e-08 | Perplexity: 34.10
# SB + Spell Correct   | Prob: 7.45e-09 | Perplexity: 42.23
# UNI:Cannot | BI:Can(4.0x) | TRI:Can(15.4x) | SB:Can(188056.9x) | SBA:Can(419026.1x)
#
# Test 8: Multiple Spelling
#
# Correct sentence: 'Natural language processing is fascinating'
# Unigram              | Prob: 2.39e-09 | Perplexity: 53.00
# Bigram               | Prob: 3.97e-08 | Perplexity: 30.21
# Trigram              | Prob: 2.18e-08 | Perplexity: 34.08
# Stupid Backoff       | Prob: 1.67e-02 | Perplexity: 2.27
# SB + Spell Correct   | Prob: 1.67e-02 | Perplexity: 2.27
#
# Wrong sentence: 'Naturel languag procesing is fascinatng'
# Unigram              | Prob: 7.47e-12 | Perplexity: 168.00
# Bigram               | Prob: 3.79e-10 | Perplexity: 76.62
# Trigram              | Prob: 3.79e-10 | Perplexity: 76.62
# Stupid Backoff       | Prob: 8.15e-42 | Perplexity: 165,096,526.65
# SB + Spell Correct   | Prob: 6.24e-42 | Perplexity: 174,154,505.86
# UNI:Can(320.0x) | BI:Can(104.9x) | TRI:Can(57.5x) | SB:Can(2044270833333326366979976411094154477568.0x) | SBA:Can(2670068027210894949219469340566624403456.0x)
#
# Test 9: Heavy Spelling
#
# Correct sentence: 'Artificial intelligence will change the world'
# Unigram              | Prob: 2.99e-11 | Perplexity: 127.32
# Bigram               | Prob: 7.37e-10 | Perplexity: 67.07
# Trigram              | Prob: 3.74e-10 | Perplexity: 76.83
# Stupid Backoff       | Prob: 2.66e-24 | Perplexity: 51,887.63
# SB + Spell Correct   | Prob: 1.36e-24 | Perplexity: 59,300.15
#
# Wrong sentence: 'Artifical inteligence wil chang the worlld'
# Unigram              | Prob: 4.45e-14 | Perplexity: 168.00
# Bigram               | Prob: 5.19e-12 | Perplexity: 76.01
# Trigram              | Prob: 5.19e-12 | Perplexity: 76.01
# Stupid Backoff       | Prob: 8.15e-52 | Perplexity: 327,176,132.07
# SB + Spell Correct   | Prob: 6.24e-52 | Perplexity: 342,067,853.79
# UNI:Can(672.0x) | BI:Can(142.1x) | TRI:Can(72.0x) | SB:Can(3261146496815277524782153728.0x) | SBA:Can(2184713375796194814879334400.0x)
#
# Test 10: Mixed Errors
#
# Correct sentence: 'Statistical methods are important in NLP'
# Unigram              | Prob: 1.20e-10 | Perplexity: 96.49
# Bigram               | Prob: 1.15e-08 | Perplexity: 38.73
# Trigram              | Prob: 1.15e-08 | Perplexity: 38.73
# Stupid Backoff       | Prob: 5.00e-02 | Perplexity: 1.82
# SB + Spell Correct   | Prob: 5.00e-02 | Perplexity: 1.82
#
# Wrong sentence: 'Statisticl methds ar importnt in NLP'
# Unigram              | Prob: 8.90e-14 | Perplexity: 149.67
# Bigram               | Prob: 1.02e-11 | Perplexity: 67.87
# Trigram              | Prob: 5.19e-12 | Perplexity: 76.01
# Stupid Backoff       | Prob: 3.26e-43 | Perplexity: 12,053,271.76
# SB + Spell Correct   | Prob: 2.18e-43 | Perplexity: 12,885,489.52
# UNI:Can(1344.0x) | BI:Can(1121.3x) | TRI:Can(2212.3x) | SB:Can(153320312500000336163061612122432920879104.0x) | SBA:Can(228862973760931071915447738511571931889664.0x)
#
# __Summary results:___
#
# Total tests: 10
# Unigram:              7/10 (70%)
# Bigram:               9/10 (90%)
# Trigram:              9/10 (90%)
# Stupid Backoff:       10/10 (100%)
# SB + Spell Correct:   10/10 (100%)
#
#  The most effective model is: Stupid Backoff
